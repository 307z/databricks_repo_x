# %%
import os, shutil, subprocess

# %%
# %sh
# Do once
curl -fsSL https://raw.githubusercontent.com/databricks/setup-cli/main/install.sh | sh

# %%
import os
os.environ["PATH"] += ":/root/bin"

# %%
# %sh 
databricks -h

# %%
workspace_prod_token = dbutils.secrets.get("worn_prod_scope", "workspace_b_token")
workspace_prod_host = "https://adb-7405615924392090.10.azuredatabricks.net"

# %%
# %sh
mkdir -p ~/.databrickscfg

# %%
# Write Databricks CLI config
config_content = f"""[WORN_PROD]
host = {workspace_prod_host}
token = {workspace_prod_token}
"""

config_path = os.path.expanduser("~/.databrickscfg")

# remove existing config
if os.path.isdir(config_path):
    shutil.rmtree(config_path)
    print(f"Removed directory: {config_path}")

with open(config_path, "w") as f:
    f.write(config_content)

print("config written")

# %%
# %sh ls ../.. | pwd

# %%
# %sh
cd /Workspace/Users/borwornpanklang@gmail.com/databricks_repo_x/MPO_PIPELINE && ls -la

# %%
# %sh
rm -rf /tmp/MPO_PIPELINE
cp -r "/Workspace/Users/borwornpanklang@gmail.com/databricks_repo_x/MPO_PIPELINE" /tmp/MPO_PIPELINE
echo "=== Files copied ==="
ls -la /tmp/MPO_PIPELINE/
echo "=== databricks.yml ==="
cat /tmp/MPO_PIPELINE/databricks.yml

# %%
# %sh
cd /tmp/MPO_PIPELINE && databricks bundle validate -t prod

# %%
# %sh
cd /tmp/MPO_PIPELINE && databricks bundle deploy -t prod
